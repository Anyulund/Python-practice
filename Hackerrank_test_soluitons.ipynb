# %% [markdown]
# <a href="https://colab.research.google.com/github/Anyulund/Python-practice/blob/main/Hackerrank_test_soluitons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Select top 3 students with highest grades top 3 descending ascending

# %%
select Student_Name, Avg(scores) as GPA
from Table
group by Student_Name
order by 1 DESC 
LIMIT 3

# %%
pairs = {}
for prod in products:
  if prod in pairs:  
     pairs[prod] += 1
  else:
    pairs[prod] = 1

print(sorted(pairs.items(), key=lambda kv_pair: kv_pair[1], reverse=True))
# Out:
# [('redShirt', 2), ('blackPants', 2), ('greenPants', 1), ('orangeShoes', 1)]

# %%
SELECT department.name,
COUNT(*)
FROM department 
INNER JOIN employee 
ON employee.id = department.id 
GROUP BY departments.id, name 
ORDER BY name;

'To debug'
CREATE PROCEDURE procedure_name() 
BEGIN
    DECLARE EXIT HANDLER FOR SQLEXCEPTION
    BEGIN
        SHOW ERRORS;  --this is the only one which you need
        ROLLBACK;   
    END; 
    START TRANSACTION;
        --query 1
        --query 2
        --query 3
    COMMIT;
END

# %%
import itertools
weights= [1.1,1.1,1.1,1.4,2.4]
n=5

total_weight = []
current_weight = 0
for weight in weights:
  current_weight = current_weight + weight
  while current_weight < 3:
    if current_weight < 3:
    total_weight.append(current_weight)

print(total_weight)
# Out:
# [1.1, 2.2]

# %%
weights= [1.1,1.1,1.1,1.4,2.4]
n=5
bsum = 3

weights_list = []
current_weight = 0
count = 0 
for i in range(0, n): 
    current_weight = weights[i]
    j = i+1
    while j <= n:
      if current_weight <= bsum: 
        print('These bags sum to less than 3 pounds', weights[i], weights[j-1])
      if current_weight > bsum or j == n: 
        break            
      current_weight = current_weight + weights[j] 
      j += 1
print('The bags are too heavy')
# Out:
# These bags sum to less than 3 pounds 1.1 1.1
# These bags sum to less than 3 pounds 1.1 1.1
# These bags sum to less than 3 pounds 1.1 1.1
# These bags sum to less than 3 pounds 1.1 1.1
# These bags sum to less than 3 pounds 1.1 1.1
# These bags sum to less than 3 pounds 1.1 1.4
# These bags sum to less than 3 pounds 1.4 1.4
# These bags sum to less than 3 pounds 2.4 2.4
# The bags are too heavy

# %%
for i in range(n): 
        curr_sum = arr[i] 
      
        # try all subarrays 
        # starting with 'i' 
        j = i + 1
        while j <= n: 
          
            if curr_sum == sum: 
                print ("Sum found between") 
                print("indexes % d and % d"%( i, j-1)) 
                  
                return 1
                  
            if curr_sum > sum or j == n: 
                break
              
            curr_sum = curr_sum + arr[j] 
            j += 1
  
    print ("No subarray found") 
    return 0
